# %%
import pandas as pd

# %% [markdown]
# https://docs.google.com/spreadsheets/d/186f9JePfK6rlRrHCcf0aD-lqEQEXCkgJlYhKlXdjZgE/edit?usp=sharing

# %%
url = 'https://docs.google.com/spreadsheets/d/186f9JePfK6rlRrHCcf0aD-lqEQEXCkgJlYhKlXdjZgE/edit?usp=sharing'

# %%
id = url.split('/')[5]

# %%
df = pd.read_csv(f'https://docs.google.com/spreadsheets/d/{id}/export?format=csv')

# %%
df
# Out:
#      Age     Sex  Job  ... Duration              Purpose default
# 0     67    male    2  ...        6             radio/TV       0
# 1     22  female    2  ...       48             radio/TV       1
# 2     49    male    1  ...       12            education       0
# 3     45    male    2  ...       42  furniture/equipment       0
# 4     53    male    2  ...       24                  car       1
# ..   ...     ...  ...  ...      ...                  ...     ...
# 995   31  female    1  ...       12  furniture/equipment       0
# 996   40    male    3  ...       30                  car       0
# 997   38    male    2  ...       12             radio/TV       0
# 998   23    male    2  ...       45             radio/TV       1
# 999   27    male    2  ...       45                  car       0
#
# [1000 rows x 10 columns]

# %%
df.groupby('Housing')['default'].agg(['count','mean'])
# Out:
#          count      mean
# Housing
# free       108  0.407407
# own        713  0.260870
# rent       179  0.391061

# %%
df['amount_bin'] = pd.cut(df['Credit amount'],5)

# %%
df.groupby('amount_bin')['default'].agg(['count','mean'])
# Out:
#                     count      mean
# amount_bin
# (231.826, 3884.8]     738  0.256098
# (3884.8, 7519.6]      177  0.384181
# (7519.6, 11154.4]      57  0.403509
# (11154.4, 14789.2]     22  0.727273
# (14789.2, 18424.0]      6  0.666667

# %%
df['amount_bin_q'] = pd.qcut(df['Credit amount'],10)

# %%
df.groupby('amount_bin_q')['default'].agg(['count','mean'])
# Out:
#                    count      mean
# amount_bin_q
# (249.999, 932.0]     101  0.306931
# (932.0, 1262.0]      100  0.300000
# (1262.0, 1479.4]      99  0.262626
# (1479.4, 1906.8]     100  0.220000
# (1906.8, 2319.5]     100  0.300000
# (2319.5, 2852.4]     100  0.240000
# (2852.4, 3590.0]     101  0.227723
# (3590.0, 4720.0]      99  0.292929
# (4720.0, 7179.4]     100  0.380000
# (7179.4, 18424.0]    100  0.470000

# %%
df.groupby('amount_bin_q')['default'].mean().plot(ylim=(0,1))

# %%
df.groupby('amount_bin_q')['default'].mean().plot(kind='bar')

# %%
df['Credit amount'].hist()

# %%
df.boxplot('Credit amount')

# %%
df.boxplot('Credit amount',by='Housing')

# %%
df.hist('Credit amount',by='Housing')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f37829b4390>,
# ...
#       dtype=object)

# %%
t = df.groupby('Housing')['Credit amount'].agg(['count','median'])

# %%
t
# Out:
#          count  median
# Housing
# free       108  3800.5
# own        713  2238.0
# rent       179  2301.0

# %%
ax1 = t['median'].plot(ylim=(0,5000))
ax2 = ax1.twinx()
t['count'].plot(ax=ax2,kind='bar',alpha=0.2)

# %%
df.plot(x='Age',y='Credit amount',kind='scatter')

# %%
df['age_bin'] = pd.cut(df['Age'],5)

# %%
t = df.groupby('age_bin')['Credit amount'].agg(['count','median'])

# %%
t
# Out:
#                 count  median
# age_bin
# (18.944, 30.2]    411  2221.0
# (30.2, 41.4]      332  2401.5
# (41.4, 52.6]      161  2348.0
# (52.6, 63.8]       68  2128.5
# (63.8, 75.0]       28  1503.0

# %%
ax1 = t['median'].plot(ylim=(0,5000))
ax2 = ax1.twinx()
t['count'].plot(ax=ax2,kind='bar',alpha=0.2,rot=45)

# %% [markdown]
# Pivot table + cut
# Plot + bar
# Hist + box plot
# Scatter

# %% [markdown]
# by Gleb Mikhaylov
#
# My YouTube channel: https://www.youtube.com/channel/UCLdAnxmoGVySnh691CwDz9Q
# My GitHub: https://github.com/glebmikha
